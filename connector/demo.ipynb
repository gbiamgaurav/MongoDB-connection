# %%
import pymongo
import pandas as pd

# %%
mongo_db_url = "mongodb+srv://cloud-gaurav:Kabali1234@cluster0.5scda40.mongodb.net/?retryWrites=true&w=majority"

client = pymongo.MongoClient(mongo_db_url)

# %%
db = client["ml"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-apyxa3q-shard-00-02.5scda40.mongodb.net:27017', 'ac-apyxa3q-shard-00-01.5scda40.mongodb.net:27017', 'ac-apyxa3q-shard-00-00.5scda40.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-y5r7ej-shard-0', tls=True), 'ml')

# %%
my_collection = db["datasets"]

# %%
print(my_collection)
# Out:
# Collection(Database(MongoClient(host=['ac-apyxa3q-shard-00-02.5scda40.mongodb.net:27017', 'ac-apyxa3q-shard-00-01.5scda40.mongodb.net:27017', 'ac-apyxa3q-shard-00-00.5scda40.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-y5r7ej-shard-0', tls=True), 'ml'), 'datasets')

# %%
## Fetch one record from the collection

one_record = my_collection.find_one()

# %%
print(one_record)
# Out:
# {'_id': ObjectId('646e1a628b2b02838ea49dbe'), 'Time': '17:02:00', 'Day_of_week': 'Monday', 'Age_band_of_driver': '18-30', 'Sex_of_driver': 'Male', 'Educational_level': 'Above high school', 'Vehicle_driver_relation': 'Employee', 'Driving_experience': '1-2yr', 'Type_of_vehicle': 'Automobile', 'Owner_of_vehicle': 'Owner', 'Service_year_of_vehicle': 'Above 10yr', 'Defect_of_vehicle': 'No defect', 'Area_accident_occured': 'Residential areas', 'Road_allignment': 'Tangent road with flat terrain', 'Types_of_Junction': 'No junction', 'Road_surface_type': 'Asphalt roads', 'Road_surface_conditions': 'Dry', 'Light_conditions': 'Daylight', 'Weather_conditions': 'Normal', 'Type_of_collision': 'Collision with roadside-parked vehicles', 'Number_of_vehicles_involved': 2, 'Number_of_casualties': 2, 'Vehicle_movement': 'Going straight', 'Casualty_class': 'na', 'Sex_of_casualty': 'na', 'Age_band_of_casualty': 'na', 'Casualty_severity': 'na', 'Pedestrian_movement': 'Not a Pedestrian', 'Cause_of_accident'
# ...

# %%
## Fetch all records 

all_records = my_collection.find()

# %%
print(all_records)

# %%
## iterate over all_records

for row in all_records:
    print(row)
# Out:
# {'_id': ObjectId('646e1a628b2b02838ea49dbe'), 'Time': '17:02:00', 'Day_of_week': 'Monday', 'Age_band_of_driver': '18-30', 'Sex_of_driver': 'Male', 'Educational_level': 'Above high school', 'Vehicle_driver_relation': 'Employee', 'Driving_experience': '1-2yr', 'Type_of_vehicle': 'Automobile', 'Owner_of_vehicle': 'Owner', 'Service_year_of_vehicle': 'Above 10yr', 'Defect_of_vehicle': 'No defect', 'Area_accident_occured': 'Residential areas', 'Road_allignment': 'Tangent road with flat terrain', 'Types_of_Junction': 'No junction', 'Road_surface_type': 'Asphalt roads', 'Road_surface_conditions': 'Dry', 'Light_conditions': 'Daylight', 'Weather_conditions': 'Normal', 'Type_of_collision': 'Collision with roadside-parked vehicles', 'Number_of_vehicles_involved': 2, 'Number_of_casualties': 2, 'Vehicle_movement': 'Going straight', 'Casualty_class': 'na', 'Sex_of_casualty': 'na', 'Age_band_of_casualty': 'na', 'Casualty_severity': 'na', 'Pedestrian_movement': 'Not a Pedestrian', 'Cause_of_accident'
# ...

# %%
all_records = my_collection.find()

# %%
print(all_records)

# %%
list_cursor = list(all_records)

# %%
print(list_cursor)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
df = pd.DataFrame(list_cursor)

# %%
df.head()
# Out:
#                         _id      Time Day_of_week Age_band_of_driver
# 0  646e1a628b2b02838ea49dbe  17:02:00      Monday              18-30  \
# 1  646e1a628b2b02838ea49dbf  17:02:00      Monday              31-50
# 2  646e1a628b2b02838ea49dc0  17:02:00      Monday              18-30
# 3  646e1a628b2b02838ea49dc1   1:06:00      Sunday              18-30
# 4  646e1a628b2b02838ea49dc2   1:06:00      Sunday              18-30
#
#   Sex_of_driver   Educational_level Vehicle_driver_relation
# 0          Male   Above high school                Employee  \
# 1          Male  Junior high school                Employee
# 2          Male  Junior high school                Employee
# 3          Male  Junior high school                Employee
# 4          Male  Junior high school                Employee
#
#   Driving_experience      Type_of_vehicle Owner_of_vehicle  ...
# 0              1-2yr           Automobile            Owner  ...  \
# ...

# %%
df.columns
# Out:
# Index(['_id', 'Time', 'Day_of_week', 'Age_band_of_driver', 'Sex_of_driver',
#        'Educational_level', 'Vehicle_driver_relation', 'Driving_experience',
#        'Type_of_vehicle', 'Owner_of_vehicle', 'Service_year_of_vehicle',
#        'Defect_of_vehicle', 'Area_accident_occured', 'Road_allignment',
#        'Types_of_Junction', 'Road_surface_type', 'Road_surface_conditions',
#        'Light_conditions', 'Weather_conditions', 'Type_of_collision',
#        'Number_of_vehicles_involved', 'Number_of_casualties',
#        'Vehicle_movement', 'Casualty_class', 'Sex_of_casualty',
#        'Age_band_of_casualty', 'Casualty_severity', 'Pedestrian_movement',
#        'Cause_of_accident', 'Lanes_or_Medians', 'Work_of_casuality',
#        'Fitness_of_casuality'],
#       dtype='object')

# %%
df.drop(columns=["_id"], axis=1)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver
# 0      17:02:00      Monday              18-30          Male  \
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience
# 0       Above high school                Employee              1-2yr  \
# 1      Junior high school                Employee         Above 10yr
# ...

# %%
df.shape
# Out:
# (12316, 32)

# %% [markdown]
# ### Fetching another dataset

# %%
client = pymongo.MongoClient(mongo_db_url)

# %%
db = client["self-projects"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['ac-apyxa3q-shard-00-02.5scda40.mongodb.net:27017', 'ac-apyxa3q-shard-00-01.5scda40.mongodb.net:27017', 'ac-apyxa3q-shard-00-00.5scda40.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-y5r7ej-shard-0', tls=True), 'self-projects')

# %%
my_collection = db["sensor_data"]

# %%
print(my_collection)
# Out:
# Collection(Database(MongoClient(host=['ac-apyxa3q-shard-00-02.5scda40.mongodb.net:27017', 'ac-apyxa3q-shard-00-01.5scda40.mongodb.net:27017', 'ac-apyxa3q-shard-00-00.5scda40.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-y5r7ej-shard-0', tls=True), 'self-projects'), 'sensor_data')

# %%
## Fetch one record from the collection

one_record = my_collection.find_one()

# %%
print(one_record)
# Out:
# {'_id': ObjectId('646e34420f2be96af2f487c2'), 'class': 'pos', 'aa_000': 153204, 'ab_000': 0, 'ac_000': 182, 'ad_000': 'na', 'ae_000': 0, 'af_000': 0, 'ag_000': 0, 'ag_001': 0, 'ag_002': 0, 'ag_003': 11804, 'ag_004': 684444, 'ag_005': 326536, 'ag_006': 31586, 'ag_007': 0, 'ag_008': 0, 'ag_009': 0, 'ah_000': 2658638, 'ai_000': 14346, 'aj_000': 0, 'ak_000': 0, 'al_000': 29384, 'am_0': 46356, 'an_000': 5566182, 'ao_000': 4426834, 'ap_000': 1571480, 'aq_000': 1120644, 'ar_000': 2, 'as_000': 0, 'at_000': 0, 'au_000': 0, 'av_000': 1368, 'ax_000': 862, 'ay_000': 0, 'ay_001': 0, 'ay_002': 0, 'ay_003': 0, 'ay_004': 0, 'ay_005': 0, 'ay_006': 0, 'ay_007': 94188, 'ay_008': 960182, 'ay_009': 0, 'az_000': 250, 'az_001': 16, 'az_002': 32, 'az_003': 146, 'az_004': 126, 'az_005': 951126, 'az_006': 91162, 'az_007': 11512, 'az_008': 0, 'az_009': 0, 'ba_000': 702994, 'ba_001': 186172, 'ba_002': 69282, 'ba_003': 36640, 'ba_004': 20698, 'ba_005': 17720, 'ba_006': 18586, 'ba_007': 2278, 'ba_008': 0, 'ba_009
# ...

# %%
## Fetch all records 

all_records = my_collection.find()

# %%
print(all_records)

# %%
## iterate over all_records

for row in all_records:
    print(row)
# Out:
# {'_id': ObjectId('646e34420f2be96af2f487c2'), 'class': 'pos', 'aa_000': 153204, 'ab_000': 0, 'ac_000': 182, 'ad_000': 'na', 'ae_000': 0, 'af_000': 0, 'ag_000': 0, 'ag_001': 0, 'ag_002': 0, 'ag_003': 11804, 'ag_004': 684444, 'ag_005': 326536, 'ag_006': 31586, 'ag_007': 0, 'ag_008': 0, 'ag_009': 0, 'ah_000': 2658638, 'ai_000': 14346, 'aj_000': 0, 'ak_000': 0, 'al_000': 29384, 'am_0': 46356, 'an_000': 5566182, 'ao_000': 4426834, 'ap_000': 1571480, 'aq_000': 1120644, 'ar_000': 2, 'as_000': 0, 'at_000': 0, 'au_000': 0, 'av_000': 1368, 'ax_000': 862, 'ay_000': 0, 'ay_001': 0, 'ay_002': 0, 'ay_003': 0, 'ay_004': 0, 'ay_005': 0, 'ay_006': 0, 'ay_007': 94188, 'ay_008': 960182, 'ay_009': 0, 'az_000': 250, 'az_001': 16, 'az_002': 32, 'az_003': 146, 'az_004': 126, 'az_005': 951126, 'az_006': 91162, 'az_007': 11512, 'az_008': 0, 'az_009': 0, 'ba_000': 702994, 'ba_001': 186172, 'ba_002': 69282, 'ba_003': 36640, 'ba_004': 20698, 'ba_005': 17720, 'ba_006': 18586, 'ba_007': 2278, 'ba_008': 0, 'ba_009
# ...

# %%
all_records = my_collection.find()

# %%
print(all_records)

# %%
list_cursor = list(all_records)

# %%
df1 = pd.DataFrame(list_cursor)

# %%
df1.head()
# Out:
#                         _id class  aa_000 ab_000 ac_000 ad_000 ae_000 af_000
# 0  646e34420f2be96af2f487c2   pos  153204      0    182     na      0      0  \
# 1  646e34420f2be96af2f487c3   pos  453236     na   2926     na      0      0
# 2  646e34420f2be96af2f487c4   pos   72504     na   1594   1052      0      0
# 3  646e34420f2be96af2f487c5   pos  762958     na     na     na     na     na
# 4  646e34420f2be96af2f487c6   pos  695994     na     na     na     na     na
#
#   ag_000  ag_001  ...    ee_001   ee_002   ee_003   ee_004   ee_005   ee_006
# 0      0       0  ...    293880   129862    26872    34044    22472    34362  \
# 1      0       0  ...  13176956  7908038  3026002  5025350  2025766  1160638
# 2      0     244  ...   2161030  1432098   372252   527514   358274   332818
# 3    776  281128  ...        na       na       na       na       na       na
# 4      0       0  ...   3141688  1397742   495544   361646    28610     5130
#
#    ee_007  ee_008 ee_009 ef_000
# ...

# %%
df1.drop(columns="_id", axis=1)
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000  ag_001
# 0       pos  153204      0         182     na      0      0      0       0  \
# 1       pos  453236     na        2926     na      0      0      0       0
# 2       pos   72504     na        1594   1052      0      0      0     244
# 3       pos  762958     na          na     na     na     na    776  281128
# 4       pos  695994     na          na     na     na     na      0       0
# ...     ...     ...    ...         ...    ...    ...    ...    ...     ...
# 36183   neg  153002     na         664    186      0      0      0       0
# 36184   neg    2286     na  2130706538    224      0      0      0       0
# 36185   neg     112      0  2130706432     18      0      0      0       0
# 36186   neg   80292     na  2130706432    494      0      0      0       0
# 36187   neg   40222     na         698    628      0      0      0       0
#
# ...

# %%
df1.shape
# Out:
# (36188, 171)
